# %%
# !pip install -q transformers peft accelerate gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 11.8 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 48.5 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.5 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.

# %%
# !ls /kaggle/input/mistral-model
# Out:
# adapter_config.json	   checkpoint-417  README.md
# adapter_model.safetensors  checkpoint-834

# %%
# !ls /kaggle/input/mistral-model/mistral_lora_adapter
# Out:
# ls: cannot access '/kaggle/input/mistral-model/mistral_lora_adapter': No such file or directory

# %%
# !ls /kaggle/input
# Out:
# mistral-model

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import torch
import os

BASE_MODEL = "mistralai/Mistral-7B-Instruct-v0.2"
LORA_PATH = "/kaggle/input/mistral-model/checkpoint-834"
OFFLOAD_DIR = "/kaggle/working/offload"

os.makedirs(OFFLOAD_DIR, exist_ok=True)

print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)

print("Loading base model with offloading...")
base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    device_map="auto",
    torch_dtype=torch.float16,
    offload_folder=OFFLOAD_DIR
)

print("Loading LoRA adapter...")
model = PeftModel.from_pretrained(base_model, LORA_PATH)
model.eval()

print("✅ Model + LoRA loaded successfully")
# Out:
# 2025-12-17 23:32:05.398033: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766014325.580125      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766014325.634684      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Loading tokenizer...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Loading base model with offloading...
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Loading LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/config.py:165: UserWarning: Unexpected keyword arguments ['alora_invocation_tokens', 'arrow_config', 'ensure_weight_tying', 'peft_version', 'target_parameters'] for class LoraConfig, these are ignored. This probably means that you're loading a configuration file that was saved using a higher version of the library and additional parameters have been introduced since. It is highly recommended to upgrade the PEFT version before continuing (e.g. by running `pip install -U peft`).
#   warnings.warn(
# ✅ Model + LoRA loaded successfully

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import torch
import os

BASE_MODEL = "mistralai/Mistral-7B-Instruct-v0.2"
LORA_PATH = "/kaggle/input/mistral-model/checkpoint-834"
OFFLOAD_DIR = "/kaggle/working/offload"

os.makedirs(OFFLOAD_DIR, exist_ok=True)

print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)

print("Loading base model with offloading...")
base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    device_map="auto",
    torch_dtype=torch.float16,
    offload_folder=OFFLOAD_DIR
)

print("Loading LoRA adapter...")
model = PeftModel.from_pretrained(
    base_model,
    LORA_PATH,
    is_trainable=False,
    offload_folder=OFFLOAD_DIR   # 👈 السطر الحاسم
)

model.eval()

print("✅ Model + LoRA loaded successfully")
# Out:
# Loading tokenizer...
# Loading base model with offloading...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/config.py:165: UserWarning: Unexpected keyword arguments ['alora_invocation_tokens', 'arrow_config', 'ensure_weight_tying', 'peft_version', 'target_parameters'] for class LoraConfig, these are ignored. This probably means that you're loading a configuration file that was saved using a higher version of the library and additional parameters have been introduced since. It is highly recommended to upgrade the PEFT version before continuing (e.g. by running `pip install -U peft`).
#   warnings.warn(
# ✅ Model + LoRA loaded successfully

# %%
def generate_response(prompt):
    # Tokenize
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generate
    outputs = model.generate(
        **inputs,
        max_new_tokens=200,
        do_sample=False,
        temperature=0.3,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    text = decoded.strip()

    # Fallback لو الرد قصير أو مش مفهوم
    if len(text.split()) < 5:
        text = (
            "I'm really sorry you're feeling this way. "
            "You're not alone, and it's okay to take things one step at a time."
        )

    return text

# %%
import gradio as gr

# =========================
# Chat function
# =========================
def chat_fn(message, history):
    response = generate_response(message)
    history.append((message, response))
    return history, ""

# =========================
# Custom CSS (Clear + Girly + Centered Title)
# =========================
custom_css = """
body {
    background: linear-gradient(135deg, #1f1f2e, #2b2b45);
}

.gradio-container {
    font-family: 'Poppins', sans-serif;
}

/* Center title */
#title {
    text-align: center;
    color: #ffd6ea;
}

/* Chat container */
#chatbot {
    background-color: #121212;
    border-radius: 22px;
    padding: 12px;
}

/* User bubble */
.message.user {
    background: linear-gradient(135deg, #ff6fae, #ff8ccf) !important;
    color: #1a1a1a;
    font-weight: 500;
    border-radius: 18px !important;
}

/* Bot bubble */
.message.bot {
    color: #000000 !important;  /* <-- UPDATED: Added !important to ensure black text */
    font-weight: 500;
    border-radius: 18px !important;
}

/* Textbox */
textarea {
    background-color: #1e1e2e !important;
    color: #ffffff !important;
    border-radius: 14px !important;
    border: 1px solid #ff8ccf !important;
}

/* Buttons */
button {
    background: linear-gradient(90deg, #ff6fae, #ff8ccf) !important;
    color: #ffffff ;
    border-radius: 14px !important;
    font-weight: bold;
}

button:hover {
    opacity: 0.92;
}
"""

# =========================
# Gradio UI
# =========================
with gr.Blocks(css=custom_css) as demo:
    
    gr.Markdown(
        """
        <h2 id="title">🌸 InnerBloom 🌸</h2>
        <p style="text-align:center; color:#fbcfe8;">
        💖 Your safe space to talk & bloom 💖
        </p>
        """
    )

    chatbot = gr.Chatbot(elem_id="chatbot", height=420)

    with gr.Row():
        msg = gr.Textbox(
            placeholder="Type your message here 💬",
            show_label=False
        )
        send = gr.Button("Send 💌")

    clear = gr.Button("Clear Chat 🧹")

    send.click(chat_fn, inputs=[msg, chatbot], outputs=[chatbot, msg])
    msg.submit(chat_fn, inputs=[msg, chatbot], outputs=[chatbot, msg])
    clear.click(lambda: [], None, chatbot)

# To run this, you would execute the script in your terminal.
demo.launch()
# Out:
# /tmp/ipykernel_47/3522074658.py:86: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(elem_id="chatbot", height=420)
# * Running on local URL:  http://127.0.0.1:7860
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# * Running on public URL: https://ef1a3dd2bd3a9435cd.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ef1a3dd2bd3a9435cd.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
